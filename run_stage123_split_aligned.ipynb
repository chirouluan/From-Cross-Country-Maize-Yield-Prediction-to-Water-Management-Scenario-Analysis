# %% [markdown]
# # CY-Bench Stage 1 → 2 → 3 消融实验（强制单一候选）
#
# 与 `run_stage123_rag_5repeats.ipynb` 完全相同的流程（Stage 1 推荐/校准筛选 → 正式五模型五折预测 → 汇总；
# Stage 2 CN 数据导出与 TabPFN 对比；Stage 3 风险诊断/恢复情景/LLM 建议），唯一区别是把两个 LLM
# advisor 的 Stage 1 特征候选各**固定为一个**：
#
# - `qwen_base` → 仅使用 `extreme_heat_drought_syndrome` 配方（复用原 CN 推荐中 `sample1_extreme_heat_drought_syndrome` 的 config，各国相同）；
# - `qwen_rag`  → 仅使用 Historical regime（各国原 RAG 推荐中的 `rag1_rag_historical_regime`）。
#
# 运行范围：国家 CN、ZA、MX、PT；模型与重复数与原文一致。所有结果写入**新目录**
# `cybench/output/stages_abl_heat_hist/`，**不会覆盖**原始 `cybench/output/stages/`。
#
# 请使用 **specllm** 内核运行。每个长任务实时输出并保存日志；中断后重跑对应单元即可从已有产物继续。

# %%
from pathlib import Path
from datetime import datetime
import json
import os
import subprocess
import sys
import time

import pandas as pd

PROJECT_ROOT = Path.cwd().resolve()
if not (PROJECT_ROOT / 'cybench').is_dir():
    raise RuntimeError(f'请从项目根目录打开 Notebook；当前目录为 {PROJECT_ROOT}')
os.chdir(PROJECT_ROOT)

COUNTRIES = ['CN', 'ZA', 'MX', 'PT']
COUNTRY_ARG = ','.join(COUNTRIES)
ADVISORS = ['hardcode', 'qwen_base', 'qwen_rag']
ADVISOR_ARG = ','.join(ADVISORS)
MODELS = ['ridge', 'xgboost', 'svr', 'cnn1d', 'transformer_flat']
REPEATS = 5
BASE_SEED = 42
DEVICE = 'cuda'

BASE = PROJECT_ROOT / 'cybench' / 'output' / 'stages_split_aligned'
STAGE_ROOT = BASE
STAGE1 = STAGE_ROOT / 'stage1_feature_engineering'
STAGE2 = STAGE_ROOT / 'stage2_tabpfn_transfer' / 'evaluation'
STAGE3 = STAGE_ROOT / 'stage3_advisory'
STAGE1_REC = STAGE1 / 'recommendations'
STAGE1_RES = STAGE1 / 'results'
STAGE2_CN = STAGE_ROOT / 'stage2_tabpfn_transfer' / 'cn_finetuning'
ORIG_STAGE1 = PROJECT_ROOT / 'cybench' / 'output' / 'stages' / 'stage1_feature_engineering'
RUN_ID = datetime.now().strftime('%Y%m%d_%H%M%S')
LOG_DIR = PROJECT_ROOT / 'cybench' / 'output' / 'logs' / f'notebook_stage123_split_aligned_{RUN_ID}'
LOG_DIR.mkdir(parents=True, exist_ok=True)

# 消融实验不调用 LLM 重新生成推荐：候选在本 notebook 中直接固定写入新 raw 目录。
REGENERATE_LLM = False

print('Python:', sys.executable)
print('Project:', PROJECT_ROOT)
print('Countries:', COUNTRY_ARG)
print('Repeats:', REPEATS, 'Seeds:', [BASE_SEED + 1009 * i for i in range(REPEATS)])
print('Regenerate missing LLM recommendations:', REGENERATE_LLM)
if 'specllm' not in sys.executable.lower():
    raise RuntimeError('当前不是 specllm Python 内核，请切换内核后重新运行。')
# Out:
# Python: d:\Anaconda\envs\specllm\python.exe
# Project: C:\Users\35454\Downloads\AgML-CY-Bench-main
# Countries: CN,ZA,MX,PT
# Repeats: 5 Seeds: [42, 1051, 2060, 3069, 4078]
# Regenerate missing LLM recommendations: False

# %% [markdown]
# ## 实验设计说明
#
# - Stage 2/3 沿用 `qwen_rag`（现被固定为 Historical regime）的 Stage 1 特征集；`hardcode` 基线不变。
# - Stage 1 仍对 hardcode / qwen_base / qwen_rag × 5 模型 × 5 次重复做正式预测与汇总。
# - 预检单元会先用强制配方在每个国家构建特征表，避免长任务中途因特征不兼容而失败。

# %%
# 强制候选写入 + 特征可构建预检
# qwen_base -> extreme_heat_drought_syndrome（复用原 CN 推荐的配方，各国相同）
# qwen_rag  -> rag_historical_regime（各国原 RAG 推荐中的 Historical regime slot）
# 只写新目录 STAGE1_REC/raw/...，不触碰原推荐目录。
import copy
import json as _json
from pathlib import Path

FORCED_QWEN_BASE_CANDIDATE = 'sample1_extreme_heat_drought_syndrome'
FORCED_QWEN_RAG_CANDIDATE = 'rag1_rag_historical_regime'
ORIG_RAW = ORIG_STAGE1 / 'recommendations' / 'raw'


def _read_json(path):
    return _json.loads(Path(path).read_text(encoding='utf-8-sig'))


def _write_json(value, path):
    path.parent.mkdir(parents=True, exist_ok=True)
    path.write_text(_json.dumps(value, indent=2, ensure_ascii=False), encoding='utf-8')


# 原 CN qwen_base 推荐中的 extreme_heat_drought_syndrome 候选（config 自包含、跨国家可复用）。
cn_base_raw = _read_json(ORIG_RAW / 'maize_CN' / 'recommendation_qwen_base.json')
cn_matches = [c for c in cn_base_raw['candidates'] if c['candidate_id'] == FORCED_QWEN_BASE_CANDIDATE]
assert len(cn_matches) == 1, f'原 CN qwen_base 推荐缺少 {FORCED_QWEN_BASE_CANDIDATE}'
forced_base_candidate = copy.deepcopy(cn_matches[0])

forced_reports = {}
for country in COUNTRIES:
    orig_rag = _read_json(ORIG_RAW / f'maize_{country}' / 'recommendation_qwen_rag.json')
    rag_cands = [c for c in orig_rag['candidates'] if c['candidate_id'] == FORCED_QWEN_RAG_CANDIDATE]
    assert len(rag_cands) == 1, f'{country} qwen_rag 原始推荐缺少 {FORCED_QWEN_RAG_CANDIDATE}'
    forced_reports[country] = {
        'qwen_rag': {**orig_rag, 'candidates': rag_cands},
        'qwen_base': {'candidates': [copy.deepcopy(forced_base_candidate)],
                      'country': country, 'advisor': 'qwen_base'},
    }
    for advisor, report in forced_reports[country].items():
        _write_json(report, STAGE1_REC / 'raw' / f'maize_{country}' / f'recommendation_{advisor}.json')

# 预检：确保两个强制配方都能在目标国家构建出特征表。
from cybench.stages.data import (
    build_feature_table,
    feature_columns,
    load_country_dataset,
    merge_features_labels,
)

for country in COUNTRIES:
    dataset = load_country_dataset('maize', country)
    configs = {
        'qwen_base': forced_base_candidate['config'],
        'qwen_rag': forced_reports[country]['qwen_rag']['candidates'][0]['config'],
    }
    for advisor, config in configs.items():
        frame = merge_features_labels(build_feature_table(dataset, config), dataset)
        print(country, advisor, 'feature_columns=', len(feature_columns(frame)))
print('强制候选已写入：', STAGE1_REC / 'raw')
# Out:
# CN qwen_base feature_columns= 100
# CN qwen_rag feature_columns= 100
# ZA qwen_base feature_columns= 112
# ZA qwen_rag feature_columns= 112
# MX qwen_base feature_columns= 126
# MX qwen_rag feature_columns= 126
# PT qwen_base feature_columns= 126
# PT qwen_rag feature_columns= 126
# 强制候选已写入： C:\Users\35454\Downloads\AgML-CY-Bench-main\cybench\output\stages_split_aligned\stage1_feature_engineering\recommendations\raw

# %%
def run_module(step_name, module, args):
    cmd = [sys.executable, '-u', '-m', module, *[str(value) for value in args]]
    log_path = LOG_DIR / f'{step_name}.log'
    print('\n' + '=' * 90)
    print(step_name)
    print(' '.join(cmd))
    print('Log:', log_path)
    started = time.time()
    with log_path.open('w', encoding='utf-8') as log:
        process = subprocess.Popen(
            cmd, cwd=PROJECT_ROOT, stdout=subprocess.PIPE, stderr=subprocess.STDOUT,
            text=True, encoding='utf-8', errors='replace', bufsize=1,
        )
        for line in process.stdout:
            print(line, end='')
            log.write(line)
            log.flush()
        return_code = process.wait()
    elapsed = time.time() - started
    state = {'step': step_name, 'module': module, 'command': cmd, 'return_code': return_code, 'elapsed_seconds': elapsed}
    (LOG_DIR / f'{step_name}.state.json').write_text(json.dumps(state, indent=2, ensure_ascii=False), encoding='utf-8')
    if return_code != 0:
        raise RuntimeError(f'{step_name} 失败，返回码 {return_code}；查看 {log_path}')
    print(f'完成：{step_name}，耗时 {elapsed / 60:.1f} 分钟')
    return state

def require_file(path):
    path = Path(path)
    if not path.is_file():
        raise FileNotFoundError(path)
    return path

# %% [markdown]
# ## Stage 1：推荐、校准期候选筛选

# %%
stage1_prepare_args = [
    '--countries', COUNTRY_ARG, '--advisors', ADVISOR_ARG,
    '--direct-candidates', '--selection-repeats', REPEATS,
    '--base-seed', BASE_SEED, '--resume',
    '--output-dir', STAGE1_REC,
]
if REGENERATE_LLM:
    stage1_prepare_args.append('--regenerate-llm')
run_module('01_stage1_prepare', 'cybench.stages.stage1_feature_engineering.prepare', stage1_prepare_args)
# Out:
# ==========================================================================================
# 01_stage1_prepare
# d:\Anaconda\envs\specllm\python.exe -u -m cybench.stages.stage1_feature_engineering.prepare --countries CN,ZA,MX,PT --advisors hardcode,qwen_base,qwen_rag --direct-candidates --selection-repeats 5 --base-seed 42 --resume --output-dir C:\Users\35454\Downloads\AgML-CY-Bench-main\cybench\output\stages_split_aligned\stage1_feature_engineering\recommendations
# Log: C:\Users\35454\Downloads\AgML-CY-Bench-main\cybench\output\logs\notebook_stage123_split_aligned_20260915_132213\01_stage1_prepare.log
# CN qwen_base: ridge=sample1_extreme_heat_drought_syndrome, xgboost=sample1_extreme_heat_drought_syndrome, svr=sample1_extreme_heat_drought_syndrome, cnn1d=sample1_extreme_heat_drought_syndrome, transformer_flat=sample1_extreme_heat_drought_syndrome
# CN qwen_rag: ridge=rag1_rag_historical_regime, xgboost=rag1_rag_historical_regime, svr=rag1_rag_historical_regime, cnn1d=rag1_rag_historical_regime, transformer_flat=rag1_rag_historical_regime
# ZA qwen_base: ridge=sample1_extreme_heat_drought_syndrome, xgboost=sample1_extreme_heat_drought_syndrome, svr=sample1_extreme_heat_drought_syndrome, cnn1d=sample1_extreme_heat_drought_syndrome, transformer_flat=sample1_extreme_heat_drought_syndrome
# ZA qwen_rag: ridge=rag1_rag_historical_regime, xgboost=rag1_rag_historical_regime, svr=rag1_rag_historical_regime, cnn1d=rag1_rag_historical_regime, transformer_flat=rag1_rag_historical_regime
# MX qwen_base: ridge=sample1_extreme_heat_drought_syndrome, xgboost=sample1_extreme_heat_drought_syndrome, svr=sample1_extreme_heat_drought_syndrome, cnn1d=sample1_extreme_heat_drought_syndrome, transformer_flat=sample1_extreme_heat_drought_syndrome
# MX qwen_rag: ridge=rag1_rag_historical_regime, xgboost=rag1_rag_historical_regime, svr=rag1_rag_historical_regime, cnn1d=rag1_rag_historical_regime, transformer_flat=rag1_rag_historical_regime
# PT qwen_base: ridge=sample1_extreme_heat_drought_syndrome, xgboost=sample1_extreme_heat_drought_syndrome, svr=sample1_extreme_heat_drought_syndrome, cnn1d=sample1_extreme_heat_drought_syndrome, transformer_flat=sample1_extreme_heat_drought_syndrome
# PT qwen_rag: ridge=rag1_rag_historical_regime, xgboost=rag1_rag_historical_regime, svr=rag1_rag_historical_regime, cnn1d=rag1_rag_historical_regime, transformer_flat=rag1_rag_historical_regime
# 完成：01_stage1_prepare，耗时 10.5 分钟
# {'step': '01_stage1_prepare',
#  'module': 'cybench.stages.stage1_feature_engineering.prepare',
#  'command': ['d:\\Anaconda\\envs\\specllm\\python.exe',
#   '-u',
#   '-m',
#   'cybench.stages.stage1_feature_engineering.prepare',
#   '--countries',
#   'CN,ZA,MX,PT',
#   '--advisors',
#   'hardcode,qwen_base,qwen_rag',
#   '--direct-candidates',
#   '--selection-repeats',
#   '5',
#   '--base-seed',
#   '42',
#   '--resume',
#   '--output-dir',
#   'C:\\Users\\35454\\Downloads\\AgML-CY-Bench-main\\cybench\\output\\stages_split_aligned\\stage1_feature_engineering\\recommendations'],
#  'return_code': 0,
#  'elapsed_seconds': 629.9743237495422}

# %% [markdown]
# ## Stage 1：外层五次正式预测与汇总
#
# > **本 notebook 相对 `run_stage123.ipynb` 的唯一改动**：Stage 1 的时间切分改为与 Stage 2 相同。
# > 原 `stage1_feature_engineering/run.py:68` 对所有国家一律取 `chronological_test_years(dataset.years, 0.3)`（最后 30%），
# > 而 `stage2_tabpfn_transfer/run.py:128-134` 对 CN 用固定的 `(2020, 2021, 2022)`。
# > 这里在 notebook 内把 Stage 1 调用的切分函数换成同一条规则（不改项目代码），
# > 于是 CN 的测试年由 2017–2022 变为 **2020–2022**，其余三国不变（两条规则本就等价）。
# > Stage 1 重算后落盘的特征表就是 Stage 2 随后要读的那一份，两个阶段的划分自此一致。

# %%
# ---- Stage 1 的切分改为与 Stage 2 相同（不改项目代码，只在 notebook 内生效） --------------
# stage1_feature_engineering/run.py:68 写死 chronological_test_years(dataset.years, 0.3)，
# 而 stage2_tabpfn_transfer/run.py:128-134 对 CN 用固定的 (2020, 2021, 2022)。
# 这里把 Stage 1 实际调用的那个函数替换成同一条规则，其余流程一字不动。
import contextlib

import cybench.stages.stage1_feature_engineering.run as _stage1

CN_STRICT_TEST_YEARS = (2020, 2021, 2022)
_current_country = {'value': None}
_original_load_country_dataset = _stage1.load_country_dataset
_original_chronological_test_years = _stage1.chronological_test_years


def _load_country_dataset(crop, country):
    # run_stage1 先加载数据集再算切分，借此记下当前国家。
    _current_country['value'] = country
    return _original_load_country_dataset(crop, country)


def _split_as_stage2(years, test_fraction=0.3):
    if _current_country['value'] == 'CN':
        available = sorted({int(year) for year in years})
        test_years = [year for year in CN_STRICT_TEST_YEARS if year in available]
        if len(test_years) != len(CN_STRICT_TEST_YEARS):
            raise ValueError(f'CN 要求完整的 {CN_STRICT_TEST_YEARS}；实际可用 {available}')
        return test_years
    return _original_chronological_test_years(years, test_fraction)


_stage1.load_country_dataset = _load_country_dataset
_stage1.chronological_test_years = _split_as_stage2


class _Tee:
    # 与 run_module 一样把这一步的输出同时写进日志文件。
    def __init__(self, *streams):
        self._streams = streams

    def write(self, text):
        for stream in self._streams:
            stream.write(text)

    def flush(self):
        for stream in self._streams:
            stream.flush()


stage1_log = LOG_DIR / '02_stage1_run.log'
with stage1_log.open('w', encoding='utf-8') as log, contextlib.redirect_stdout(_Tee(sys.stdout, log)):
    print('Stage 1 切分：与 Stage 2 相同（CN 固定 2020-2022，其余国家最后 30%）')
    stage1_summary = _stage1.run_stage1(
        COUNTRIES, ADVISORS, MODELS,
        config_dir=STAGE1_REC / 'selected_configs',
        output_dir=STAGE1_RES,
        epochs=50,
        resume=True,
        repeats=REPEATS,
        base_seed=BASE_SEED,
    )
print('Stage 1 完成，日志：', stage1_log)

run_module('03_stage1_summarize', 'cybench.stages.stage1_feature_engineering.summarize',
    ['--input', STAGE1_RES / 'metrics_all.csv', '--output-dir', STAGE1_RES])
display(pd.read_csv(require_file(STAGE1 / 'results' / 'metrics_summary.csv')).query("split == 'test'"))
# Out:
# Stage 1 切分：与 Stage 2 相同（CN 固定 2020-2022，其余国家最后 30%）
# CN hardcode ridge
#   checkpoint written
# CN hardcode xgboost
#   checkpoint written
# CN hardcode svr
#   checkpoint written
# CN hardcode cnn1d
#   checkpoint written
# CN hardcode transformer_flat
#   checkpoint written
# CN qwen_base ridge
#   checkpoint written
# CN qwen_base xgboost
#   checkpoint written
# CN qwen_base svr
#   checkpoint written
# CN qwen_base cnn1d
#   checkpoint written
# CN qwen_base transformer_flat
#   checkpoint written
# CN qwen_rag ridge
#   checkpoint written
# CN qwen_rag xgboost
#   checkpoint written
# CN qwen_rag svr
#   checkpoint written
# CN qwen_rag cnn1d
#   checkpoint written
# CN qwen_rag transformer_flat
#   checkpoint written
# ZA hardcode ridge
#   checkpoint written
# ZA hardcode xgboost
#   checkpoint written
# ZA hardcode svr
#   checkpoint written
# ZA hardcode cnn1d
#   checkpoint written
# ZA hardcode transformer_flat
#   checkpoint written
# ZA qwen_base ridge
#   checkpoint written
# ZA qwen_base xgboost
#   checkpoint written
# ZA qwen_base svr
#   checkpoint written
# ZA qwen_base cnn1d
#   checkpoint written
# ZA qwen_base transformer_flat
#   checkpoint written
# ZA qwen_rag ridge
#   checkpoint written
# ZA qwen_rag xgboost
#   checkpoint written
# ZA qwen_rag svr
#   checkpoint written
# ZA qwen_rag cnn1d
#   checkpoint written
# ZA qwen_rag transformer_flat
#   checkpoint written
# MX hardcode ridge
#   checkpoint written
# MX hardcode xgboost
#   checkpoint written
# MX hardcode svr
#   checkpoint written
# MX hardcode cnn1d
#   checkpoint written
# MX hardcode transformer_flat
#   checkpoint written
# MX qwen_base ridge
#   checkpoint written
# MX qwen_base xgboost
#   checkpoint written
# MX qwen_base svr
#   checkpoint written
# MX qwen_base cnn1d
#   checkpoint written
# MX qwen_base transformer_flat
#   checkpoint written
# MX qwen_rag ridge
#   checkpoint written
# MX qwen_rag xgboost
#   checkpoint written
# MX qwen_rag svr
#   checkpoint written
# MX qwen_rag cnn1d
#   checkpoint written
# MX qwen_rag transformer_flat
#   checkpoint written
# PT hardcode ridge
#   checkpoint written
# PT hardcode xgboost
#   checkpoint written
# PT hardcode svr
#   checkpoint written
# PT hardcode cnn1d
#   checkpoint written
# PT hardcode transformer_flat
#   checkpoint written
# PT qwen_base ridge
#   checkpoint written
# PT qwen_base xgboost
#   checkpoint written
# PT qwen_base svr
#   checkpoint written
# PT qwen_base cnn1d
#   checkpoint written
# PT qwen_base transformer_flat
#   checkpoint written
# PT qwen_rag ridge
#   checkpoint written
# PT qwen_rag xgboost
#   checkpoint written
# PT qwen_rag svr
#   checkpoint written
# PT qwen_rag cnn1d
#   checkpoint written
# PT qwen_rag transformer_flat
#   checkpoint written
# Stage 1 完成，日志： C:\Users\35454\Downloads\AgML-CY-Bench-main\cybench\output\logs\notebook_stage123_split_aligned_20260915_132213\02_stage1_run.log
#
# ==========================================================================================
# 03_stage1_summarize
# d:\Anaconda\envs\specllm\python.exe -u -m cybench.stages.stage1_feature_engineering.summarize --input C:\Users\35454\Downloads\AgML-CY-Bench-main\cybench\output\stages_split_aligned\stage1_feature_engineering\results\metrics_all.csv --output-dir C:\Users\35454\Downloads\AgML-CY-Bench-main\cybench\output\stages_split_aligned\stage1_feature_engineering\results
# Log: C:\Users\35454\Downloads\AgML-CY-Bench-main\cybench\output\logs\notebook_stage123_split_aligned_20260915_132213\03_stage1_summarize.log
#            model   advisor  mean_nrmse  median_nrmse  mean_r2  mean_mape  mean_kge
#            cnn1d  hardcode   30.002835      26.07704 0.438765   0.307475  0.613030
#            cnn1d qwen_base   31.465620      27.54292 0.392175   0.321770  0.643390
#            cnn1d  qwen_rag   29.050270      26.46579 0.453230   0.276105  0.643520
#            ridge  hardcode   25.206850      23.76630 0.566900   0.249900  0.712600
#            ridge qwen_base   29.467200      24.27080 0.477675   0.281575  0.710950
#            ridge  qwen_rag   26.820375      24.94285 0.512650   0.258175  0.684350
#              svr  hardcode   25.050850      24.30030 0.573500   0.239750  0.714750
#              svr qwen_base   25.873425      25.05015 0.544900   0.255050  0.710550
#              svr  qwen_rag   23.619375      23.19375 0.614975   0.223800  0.726250
# transformer_flat  hardcode   36.185835      28.27616 0.264655   0.353780  0.395445
# transformer_flat qwen_base   36.268295      28.53581 0.264190   0.355070  0.380225
# transformer_flat  qwen_rag   35.633380      28.05474 0.288215   0.356460  0.446905
#          xgboost  hardcode   27.909920      26.28726 0.495135   0.273545  0.683730
#          xgboost qwen_base   27.479260      24.88600 0.515645   0.272260  0.685900
#          xgboost  qwen_rag   26.747045      25.00538 0.534730   0.262545  0.690030
# 完成：03_stage1_summarize，耗时 0.1 分钟
#     country    advisor             model  \
# 0        CN   hardcode             cnn1d
# 2        CN   hardcode             ridge
# 4        CN   hardcode               svr
# 6        CN   hardcode  transformer_flat
# 8        CN   hardcode           xgboost
# 10       CN  qwen_base             cnn1d
# 12       CN  qwen_base             ridge
# 14       CN  qwen_base               svr
# 16       CN  qwen_base  transformer_flat
# 18       CN  qwen_base           xgboost
# 20       CN   qwen_rag             cnn1d
# 22       CN   qwen_rag             ridge
# 24       CN   qwen_rag               svr
# 26       CN   qwen_rag  transformer_flat
# 28       CN   qwen_rag           xgboost
# 30       MX   hardcode             cnn1d
# 32       MX   hardcode             ridge
# 34       MX   hardcode               svr
# 36       MX   hardcode  transformer_flat
# 38       MX   hardcode           xgboost
# 40       MX  qwen_base             cnn1d
# 42       MX  qwen_base             ridge
# 44       MX  qwen_base               svr
# 46       MX  qwen_base  transformer_flat
# 48       MX  qwen_base           xgboost
# 50       MX   qwen_rag             cnn1d
# 52       MX   qwen_rag             ridge
# 54       MX   qwen_rag               svr
# 56       MX   qwen_rag  transformer_flat
# 58       MX   qwen_rag           xgboost
# 60       PT   hardcode             cnn1d
# 62       PT   hardcode             ridge
# 64       PT   hardcode               svr
# 66       PT   hardcode  transformer_flat
# 68       PT   hardcode           xgboost
# 70       PT  qwen_base             cnn1d
# 72       PT  qwen_base             ridge
# 74       PT  qwen_base               svr
# 76       PT  qwen_base  transformer_flat
# 78       PT  qwen_base           xgboost
# 80       PT   qwen_rag             cnn1d
# 82       PT   qwen_rag             ridge
# 84       PT   qwen_rag               svr
# 86       PT   qwen_rag  transformer_flat
# 88       PT   qwen_rag           xgboost
# 90       ZA   hardcode             cnn1d
# 92       ZA   hardcode             ridge
# 94       ZA   hardcode               svr
# 96       ZA   hardcode  transformer_flat
# 98       ZA   hardcode           xgboost
# 100      ZA  qwen_base             cnn1d
# 102      ZA  qwen_base             ridge
# 104      ZA  qwen_base               svr
# 106      ZA  qwen_base  transformer_flat
# 108      ZA  qwen_base           xgboost
# 110      ZA   qwen_rag             cnn1d
# 112      ZA   qwen_rag             ridge
# 114      ZA   qwen_rag               svr
# 116      ZA   qwen_rag  transformer_flat
# 118      ZA   qwen_rag           xgboost
#
#                               candidate_id  selected_k split  mape_mean  \
# 0                                 baseline          60  test    0.11126
# 2                                 baseline          60  test    0.10060
# 4                                 baseline          60  test    0.09210
# 6                                 baseline          60  test    0.10062
# 8                                 baseline          60  test    0.09488
# 10   sample1_extreme_heat_drought_syndrome          60  test    0.10860
# 12   sample1_extreme_heat_drought_syndrome          60  test    0.10680
# 14   sample1_extreme_heat_drought_syndrome          60  test    0.09480
# 16   sample1_extreme_heat_drought_syndrome          60  test    0.09932
# 18   sample1_extreme_heat_drought_syndrome          60  test    0.09990
# 20              rag1_rag_historical_regime          60  test    0.10706
# 22              rag1_rag_historical_regime          60  test    0.10810
# 24              rag1_rag_historical_regime          60  test    0.08290
# 26              rag1_rag_historical_regime          60  test    0.09948
# 28              rag1_rag_historical_regime          60  test    0.09444
# 30                                baseline          60  test    0.68516
# 32                                baseline          60  test    0.47560
# 34                                baseline          60  test    0.47640
# 36                                baseline          60  test    0.83046
# 38                                baseline          60  test    0.60182
# 40   sample1_extreme_heat_drought_syndrome          60  test    0.72800
# 42   sample1_extreme_heat_drought_syndrome          60  test    0.58950
# 44   sample1_extreme_heat_drought_syndrome          60  test    0.53130
# 46   sample1_extreme_heat_drought_syndrome          60  test    0.84168
# 48   sample1_extreme_heat_drought_syndrome          60  test    0.60000
# 50              rag1_rag_historical_regime          60  test    0.54954
# 52              rag1_rag_historical_regime          60  test    0.50170
# 54              rag1_rag_historical_regime          60  test    0.43400
# 56              rag1_rag_historical_regime          60  test    0.84062
# 58              rag1_rag_historical_regime          60  test    0.57684
# 60                                baseline          60  test    0.25342
# 62                                baseline          60  test    0.24520
# 64                                baseline          60  test    0.20890
# 66                                baseline          60  test    0.29630
# 68                                baseline          60  test    0.22100
# 70   sample1_extreme_heat_drought_syndrome          60  test    0.25894
# 72   sample1_extreme_heat_drought_syndrome          60  test    0.23820
# 74   sample1_extreme_heat_drought_syndrome          60  test    0.21180
# 76   sample1_extreme_heat_drought_syndrome          60  test    0.28568
# 78   sample1_extreme_heat_drought_syndrome          60  test    0.20988
# 80              rag1_rag_historical_regime          60  test    0.26348
# 82              rag1_rag_historical_regime          60  test    0.23740
# 84              rag1_rag_historical_regime          60  test    0.21140
# 86              rag1_rag_historical_regime          60  test    0.29600
# 88              rag1_rag_historical_regime          60  test    0.20568
# 90                                baseline          60  test    0.18006
# 92                                baseline          60  test    0.17820
# 94                                baseline          60  test    0.18160
# 96                                baseline          60  test    0.18774
# 98                                baseline          60  test    0.17648
# 100  sample1_extreme_heat_drought_syndrome          60  test    0.19154
# 102  sample1_extreme_heat_drought_syndrome          60  test    0.19180
# 104  sample1_extreme_heat_drought_syndrome          60  test    0.18230
# 106  sample1_extreme_heat_drought_syndrome          60  test    0.19360
# 108  sample1_extreme_heat_drought_syndrome          60  test    0.17926
# 110             rag1_rag_historical_regime          60  test    0.18434
# 112             rag1_rag_historical_regime          60  test    0.18550
# 114             rag1_rag_historical_regime          60  test    0.16690
# 116             rag1_rag_historical_regime          60  test    0.18974
# 118             rag1_rag_historical_regime          60  test    0.17322
#
#      normalized_rmse_mean   r_mean  r2_mean  kge_mean  mape_variance  \
# 0                13.02210  0.75896  0.53302   0.67014   2.000800e-05
# 2                11.99180  0.84840  0.60430   0.76490   0.000000e+00
# 4                11.06360  0.86790  0.66320   0.80800   0.000000e+00
# 6                13.11766  0.77520  0.52604   0.64014   1.609700e-05
# 8                11.38592  0.89360  0.64316   0.80424   2.597000e-06
# 10               12.84826  0.76996  0.54512   0.69348   9.515000e-06
# 12               12.90490  0.84020  0.54180   0.76060   0.000000e+00
# 14               11.44870  0.85970  0.63930   0.78710   0.000000e+00
# 16               12.72242  0.78308  0.55442   0.67482   5.997000e-06
# 18               12.03464  0.88346  0.60136   0.76672   5.345000e-06
# 20               12.80200  0.78744  0.54864   0.71834   1.681800e-05
# 22               12.98810  0.84550  0.53580   0.74680   0.000000e+00
# 24               10.47960  0.87470  0.69780   0.80480   0.000000e+00
# 26               12.49992  0.80770  0.56980   0.65824   1.032200e-05
# 28               11.28310  0.89368  0.64968   0.79344   5.730000e-07
# 30               54.83516  0.72810  0.48430   0.48656   3.343023e-03
# 32               41.30300  0.84900  0.70840   0.74590   0.000000e+00
# 34               40.53920  0.86830  0.71910   0.66130   0.000000e+00
# 36               75.07336  0.10928  0.03608  -0.26242   1.207878e-03
# 38               47.67924  0.82556  0.61104   0.56744   3.701020e-04
# 40               57.92838  0.70114  0.42588   0.53164   4.706345e-03
# 22                   0.000000    0.000000     0.000000      0.000000
# 24                   0.000000    0.000000     0.000000      0.000000
# 26                   0.120184    0.000146     0.000564      0.000470
# 28                   0.002740    0.000003     0.000011      0.000063
# 30                  12.810977    0.002939     0.004403      0.001181
# 32                   0.000000    0.000000     0.000000      0.000000
# 34                   0.000000    0.000000     0.000000      0.000000
# 36                   4.410582    0.037367     0.002875      0.052182
# 38                   2.846497    0.000309     0.000729      0.000403
# 40                   4.204946    0.000299     0.001649      0.004784
# 42                   0.000000    0.000000     0.000000      0.000000
# 44                   0.000000    0.000000     0.000000      0.000000
# 46                   8.973069    0.044312     0.005628      0.067820
# 48                   3.987011    0.000585     0.001099      0.000206
# 50                   0.653495    0.000044     0.000194      0.000340
# 52                   0.000000    0.000000     0.000000      0.000000
# 54                   0.000000    0.000000     0.000000      0.000000
# 56                   5.137080    0.011400     0.003309      0.040202
# 58                   1.928298    0.000203     0.000479      0.000323
# 60                   2.464436    0.000550     0.006638      0.000820
# 62                   0.000000    0.000000     0.000000      0.000000
# 64                   0.000000    0.000000     0.000000      0.000000
# 66                   8.665534    0.013091     0.031993      0.016304
# 68                   0.194122    0.000017     0.000446      0.000094
# 70                   0.555223    0.000098     0.001588      0.000128
# 72                   0.000000    0.000000     0.000000      0.000000
# 74                   0.000000    0.000000     0.000000      0.000000
# 76                  10.304893    0.005872     0.036476      0.013631
# 78                   0.498962    0.000108     0.001094      0.000172
# 80                   0.778215    0.000277     0.002130      0.000286
# 82                   0.000000    0.000000     0.000000      0.000000
# 84                   0.000000    0.000000     0.000000      0.000000
# 86                   9.624423    0.014373     0.034247      0.016039
# 88                   0.292199    0.000015     0.000580      0.000038
# 90                   0.842066    0.000177     0.001656      0.000534
# 92                   0.000000    0.000000     0.000000      0.000000
# 94                   0.000000    0.000000     0.000000      0.000000
# 96                   0.094334    0.000107     0.000189      0.000310
# 98                   0.257516    0.000140     0.000622      0.000110
# 100                  1.065096    0.000243     0.002425      0.000229
# 102                  0.000000    0.000000     0.000000      0.000000
# 104                  0.000000    0.000000     0.000000      0.000000
# 106                  0.622984    0.000178     0.001325      0.002156
# 108                  0.302858    0.000069     0.000604      0.000115
# 110                  0.525614    0.000104     0.001029      0.000185
# 112                  0.000000    0.000000     0.000000      0.000000
# 114                  0.000000    0.000000     0.000000      0.000000
# 116                  0.426851    0.000108     0.000822      0.000626
# 118                  0.045059    0.000034     0.000103      0.000043

# %% [markdown]
# ## Stage 2：RAG 特征上的原始/农业继续训练 TabPFN

# %%
run_module('04_stage2_prepare_cn', 'cybench.stages.stage2_tabpfn_transfer.prepare_cn_data',
    ['--crop', 'maize', '--stage1-output-dir', STAGE1, '--output-dir', STAGE2_CN])
run_module(
    '05_stage2_run', 'cybench.stages.stage2_tabpfn_transfer.run',
    ['--countries', COUNTRY_ARG, '--device', DEVICE, '--repeats', REPEATS,
     '--base-seed', BASE_SEED, '--resume',
     '--stage1-output-dir', STAGE1, '--output-dir', STAGE2],
)
display(pd.read_csv(require_file(STAGE2 / 'metrics_summary.csv')).query("split == 'test'"))
# Out:
# ==========================================================================================
# 04_stage2_prepare_cn
# d:\Anaconda\envs\specllm\python.exe -u -m cybench.stages.stage2_tabpfn_transfer.prepare_cn_data --crop maize --stage1-output-dir C:\Users\35454\Downloads\AgML-CY-Bench-main\cybench\output\stages_split_aligned\stage1_feature_engineering --output-dir C:\Users\35454\Downloads\AgML-CY-Bench-main\cybench\output\stages_split_aligned\stage2_tabpfn_transfer\cn_finetuning
# Log: C:\Users\35454\Downloads\AgML-CY-Bench-main\cybench\output\logs\notebook_stage123_split_aligned_20260915_132213\04_stage2_prepare_cn.log
# {
#   "schema_version": 1,
#   "created_at_utc": "2026-09-15T05:42:50.815588+00:00",
#   "crop": "maize",
#   "source_country": "CN",
#   "feature_protocol": "Stage 1 Base-Qwen structured-CSV RAG features",
#   "feature_columns": [
#     "awc",
#     "bulk_density",
#     "max_cum_gdd1",
#     "max_cum_gdd2",
#     "max_cum_gdd3",
#     "max_cum_gdd4",
#     "max_cum_gdd5",
#     "max_cum_gdd6",
#     "max_cum_gdd7",
#     "max_cum_prec1",
#     "max_cum_prec2",
#     "max_cum_prec3",
#     "max_cum_prec4",
#     "max_cum_prec5",
#     "max_cum_prec6",
#     "max_cum_prec7",
#     "mean_cum_cwb1",
#     "mean_cum_cwb2",
#     "mean_cum_cwb3",
#     "mean_cum_cwb4",
#     "mean_cum_cwb5",
#     "mean_cum_cwb6",
#     "mean_cum_cwb7",
#     "mean_prec1",
#     "mean_prec2",
#     "mean_prec3",
#     "mean_prec4",
#     "mean_prec5",
#     "mean_prec6",
#     "mean_prec7",
#     "mean_rad1",
#     "mean_rad2",
#     "mean_rad3",
#     "mean_rad4",
#     "mean_rad5",
#     "mean_rad6",
#     "mean_rad7",
#     "mean_tavg1",
#     "mean_tavg2",
#     "mean_tavg3",
#     "mean_tavg4",
#     "mean_tavg5",
#     "mean_tavg6",
#     "mean_tavg7",
#     "mean_tmax1",
#     "mean_tmax2",
#     "mean_tmax3",
#     "mean_tmax4",
#     "mean_tmax5",
#     "mean_tmax6",
#     "mean_tmax7",
#     "mean_tmin1",
#     "mean_tmin2",
#     "mean_tmin3",
#     "mean_tmin4",
#     "mean_tmin5",
#     "mean_tmin6",
#     "mean_tmin7",
#     "tmin<0.395p1",
#     "tmin<0.395p2",
#     "tmin<0.395p3",
#     "tmin<0.395p4",
#     "tmin<0.395p5",
#     "tmin<0.395p6",
#     "tmin<0.395p7",
#     "tmax>36.485p1",
#     "tmax>36.485p2",
#     "tmax>36.485p3",
#     "tmax>36.485p4",
#     "tmax>36.485p5",
#     "tmax>36.485p6",
#     "tmax>36.485p7",
#     "prec<6.425p1",
#     "prec<6.425p2",
#     "prec<6.425p3",
#     "prec<6.425p4",
#     "prec<6.425p5",
#     "prec<6.425p6",
#     "prec<6.425p7",
#     "median_cum_fpar1",
#     "median_cum_fpar2",
#     "median_cum_fpar3",
#     "median_cum_fpar4",
#     "median_cum_fpar5",
#     "median_cum_fpar6",
#     "median_cum_fpar7",
#     "median_cum_ndvi1",
#     "median_cum_ndvi2",
#     "median_cum_ndvi3",
#     "median_cum_ndvi4",
#     "median_cum_ndvi5",
#     "median_cum_ndvi6",
#     "median_cum_ndvi7",
#     "median_ssm1",
#     "median_ssm2",
#     "median_ssm3",
#     "median_ssm4",
#     "median_ssm5",
#     "median_ssm6",
#     "median_ssm7"
#   ],
#   "train_years": [
#     2003,
#     2004,
#     2005,
#     2006,
#     2007,
#     2008,
#     2009,
#     2010,
#     2011,
#     2012,
#     2013,
#     2014,
#     2015,
#     2016,
#     2017,
#     2018
#   ],
#   "validation_years": [
#     2019,
#     2020,
#     2021,
#     2022
#   ],
#   "train_rows": 482,
#   "validation_rows": 120,
#   "files": {
#     "maize_CN_train.csv": "17421566c02527366bac050665105d2042b1a438575ef1384fe3adc46b6319e2",
#     "maize_CN_validation.csv": "022268a41a08c5f9e3656683fef6d7b249015655ce04a88f972b229e5ecea0ac"
#   },
#   "trainer": {
#     "implementation": null,
#     "base_checkpoint_sha256": null,
#     "hyperparameters": null,
#     "output_checkpoint": null,
#     "output_checkpoint_sha256": null
#   }
# }
# 完成：04_stage2_prepare_cn，耗时 0.0 分钟
#
# ==========================================================================================
# 05_stage2_run
# d:\Anaconda\envs\specllm\python.exe -u -m cybench.stages.stage2_tabpfn_transfer.run --countries CN,ZA,MX,PT --device cuda --repeats 5 --base-seed 42 --resume --stage1-output-dir C:\Users\35454\Downloads\AgML-CY-Bench-main\cybench\output\stages_split_aligned\stage1_feature_engineering --output-dir C:\Users\35454\Downloads\AgML-CY-Bench-main\cybench\output\stages_split_aligned\stage2_tabpfn_transfer\evaluation
# Log: C:\Users\35454\Downloads\AgML-CY-Bench-main\cybench\output\logs\notebook_stage123_split_aligned_20260915_132213\05_stage2_run.log
# CN tabpfn_base (100 RAG-selected features)
#   checkpoint written
# CN tabpfn_cn_finetuned (100 RAG-selected features)
#   checkpoint written
# ZA tabpfn_base (112 RAG-selected features)
#   checkpoint written
# ZA tabpfn_cn_finetuned (112 RAG-selected features)
#   checkpoint written
# MX tabpfn_base (126 RAG-selected features)
#   checkpoint written
# MX tabpfn_cn_finetuned (126 RAG-selected features)
#   checkpoint written
# PT tabpfn_base (126 RAG-selected features)
#   checkpoint written
# PT tabpfn_cn_finetuned (126 RAG-selected features)
#   checkpoint written
# country               model                                                checkpoint_sha256                    test_years  n_features split  mape_mean  normalized_rmse_mean  r_mean  r2_mean  kge_mean  mape_variance  normalized_rmse_variance   r_variance  r2_variance  kge_variance
#      CN         tabpfn_base 311ce18d97e9533d8585eaadafe040fbdd8070533209ed8696641dadc97a7301                2020;2021;2022         100  test    0.05920               7.04646 0.95498  0.86334   0.92554   4.200000e-07                  0.013781 2.807000e-06 2.065300e-05  4.278000e-06
#      CN         tabpfn_base 311ce18d97e9533d8585eaadafe040fbdd8070533209ed8696641dadc97a7301                2020;2021;2022         100 train    0.02290               3.48630 0.98840  0.97602   0.95976   7.650000e-07                  0.026233 1.250000e-06 4.777000e-06  4.608000e-06
#      CN tabpfn_cn_finetuned 53119ca48958a7b7eb5ca06752eecc2348f0b2ffa58d45d4f5ae79f02793f630                2020;2021;2022         100  test    0.05764               6.89936 0.95492  0.86902   0.92412   4.030000e-07                  0.014618 2.832000e-06 2.136200e-05  4.027000e-06
#      CN tabpfn_cn_finetuned 53119ca48958a7b7eb5ca06752eecc2348f0b2ffa58d45d4f5ae79f02793f630                2020;2021;2022         100 train    0.02358               3.73328 0.98702  0.97252   0.95326   6.270000e-07                  0.010514 4.520000e-07 2.342000e-06  1.130800e-05
#      MX         tabpfn_base 311ce18d97e9533d8585eaadafe040fbdd8070533209ed8696641dadc97a7301                          2022         126  test    0.31746              28.62632 0.94346  0.85982   0.77788   2.709080e-04                  0.853173 2.351300e-05 8.114200e-05  8.442000e-06
#      MX         tabpfn_base 311ce18d97e9533d8585eaadafe040fbdd8070533209ed8696641dadc97a7301                          2022         126 train    0.01530               1.95476 0.99966  0.99906   0.98398   9.050000e-07                  0.017797 3.000000e-09 1.300000e-08  3.262000e-06
#      MX tabpfn_cn_finetuned 53119ca48958a7b7eb5ca06752eecc2348f0b2ffa58d45d4f5ae79f02793f630                          2022         126  test    0.31396              28.30110 0.94646  0.86304   0.77552   1.372630e-04                  0.378093 1.232300e-05 3.553800e-05  9.512000e-06
#      MX tabpfn_cn_finetuned 53119ca48958a7b7eb5ca06752eecc2348f0b2ffa58d45d4f5ae79f02793f630                          2022         126 train    0.02030               2.24406 0.99970  0.99874   0.97374   2.800000e-07                  0.004642 0.000000e+00 8.000000e-09  8.680000e-07
#      PT         tabpfn_base 311ce18d97e9533d8585eaadafe040fbdd8070533209ed8696641dadc97a7
# 10              25.07390  0.88300  0.47116   0.68914   1.596500e-05
# 12              18.34962  0.94202  0.65702   0.72288   3.717000e-06
# 14              17.83746  0.94162  0.67592   0.73570   2.117000e-06
#
#     normalized_rmse_variance  r_variance  r2_variance  kge_variance
# 0                   0.013781    0.000003     0.000021      0.000004
# 2                   0.014618    0.000003     0.000021      0.000004
# 4                   0.853173    0.000024     0.000081      0.000008
# 6                   0.378093    0.000012     0.000036      0.000010
# 8                   0.306641    0.000018     0.000575      0.000088
# 10                  0.252116    0.000024     0.000452      0.000084
# 12                  0.057406    0.000014     0.000081      0.000015
# 14                  0.030693    0.000023     0.000041      0.000059

# %% [markdown]
# ## Stage 3：风险诊断、受约束恢复情景与 LLM 建议
#
# Stage 3 只运行 `qwen_rag` 分支。`qwen_base`（无检索退化参考）与 `deterministic_policy`（确定性策略）
# 不再生成，相关旧产物目录需另行清理。

# %%
run_module(
    '06_stage3_run', 'cybench.stages.stage3_advisory.run',
    ['--countries', COUNTRY_ARG, '--repeats', REPEATS, '--base-seed', BASE_SEED,
     '--advisors', 'qwen_rag',
     '--stage1-output-dir', STAGE1, '--stage2-output-dir', STAGE2, '--output-dir', STAGE3],
)
# Out:
# ==========================================================================================
# 06_stage3_run
# d:\Anaconda\envs\specllm\python.exe -u -m cybench.stages.stage3_advisory.run --countries CN,ZA,MX,PT --repeats 5 --base-seed 42 --advisors qwen_rag --stage1-output-dir C:\Users\35454\Downloads\AgML-CY-Bench-main\cybench\output\stages_split_aligned\stage1_feature_engineering --stage2-output-dir C:\Users\35454\Downloads\AgML-CY-Bench-main\cybench\output\stages_split_aligned\stage2_tabpfn_transfer\evaluation --output-dir C:\Users\35454\Downloads\AgML-CY-Bench-main\cybench\output\stages_split_aligned\stage3_advisory
# Log: C:\Users\35454\Downloads\AgML-CY-Bench-main\cybench\output\logs\notebook_stage123_split_aligned_20260915_132213\06_stage3_run.log
#   LLM advisor 'stress_scenario_policy': loaded from cache
#   LLM advisor 'stress_adaptation_advice': generating recommendation...
# Loading LLM from C:\Users\35454\Downloads\AgML-CY-Bench-main\LLM\Qwen3.5-9B...
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Exception in thread Thread-5384 (_readerthread):
# Traceback (most recent call last):
#   File "d:\Anaconda\envs\specllm\Lib\threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "d:\Anaconda\envs\specllm\Lib\threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "d:\Anaconda\envs\specllm\Lib\subprocess.py", line 1599, in _readerthread
#     buffer.append(fh.read())
#                   ^^^^^^^^^
#   File "<frozen codecs>", line 322, in decode
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb2 in position 7: invalid start byte
# W0915 13:47:00.161000 30528 site-packages\torch\utils\flop_counter.py:29] triton not found; flop counting will not work for triton kernels
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
#
# Loading weights:   0%|          | 0/427 [00:00<?, ?it/s]
# Loading weights:   0%|          | 1/427 [00:01<07:41,  1.08s/it]
# Loading weights:   0%|          | 2/427 [00:02<08:03,  1.14s/it]d:\Anaconda\envs\specllm\Lib\site-packages\bitsandbytes\backends\cuda\ops.py:213: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
#
# Loading weights:   2%|▏         | 10/427 [00:02<01:06,  6.27it/s]
# Loading weights:   3%|▎         | 14/427 [00:02<00:46,  8.96it/s]
# Loading weights:   6%|▌         | 24/427 [00:02<00:21, 18.52it/s]
# Loading weights:   7%|▋         | 30/427 [00:02<00:19, 20.46it/s]
# Loading weights:  10%|▉         | 41/427 [00:02<00:12, 31.24it/s]
# Loading weights:  11%|█         | 47/427 [00:03<00:13, 28.69it/s]
# Loading weights:  13%|█▎        | 54/427 [00:03<00:11, 33.46it/s]
# Loading weights:  15%|█▌        | 66/427 [00:03<00:08, 44.85it/s]
# Loading weights:  17%|█▋        | 72/427 [00:03<00:07, 46.17it/s]
# Loading weights:  19%|█▊        | 80/427 [00:03<00:07, 48.66it/s]
# Loading weights:  20%|██        | 86/427 [00:03<00:06, 49.48it/s]
# Loading weights:  22%|██▏       | 94/427 [00:04<00:06, 51.27it/s]
# Loading weights:  70%|██████▉   | 298/427 [00:07<00:03, 41.73it/s]
# Loading weights:  71%|███████   | 304/427 [00:08<00:05, 23.07it/s]
# Loading weights:  72%|███████▏  | 309/427 [00:08<00:05, 21.85it/s]
# Loading weights:  73%|███████▎  | 313/427 [00:08<00:05, 19.76it/s]
# Loading weights:  75%|███████▍  | 319/427 [00:08<00:04, 24.57it/s]
# Loading weights:  77%|███████▋  | 328/427 [00:09<00:02, 33.65it/s]
# Loading weights:  78%|███████▊  | 333/427 [00:09<00:03, 26.73it/s]
# Loading weights:  81%|████████  | 344/427 [00:09<00:02, 38.05it/s]
# Loading weights:  82%|████████▏ | 350/427 [00:09<00:02, 31.86it/s]
# Loading weights:  83%|████████▎ | 356/427 [00:09<00:01, 35.58it/s]
# Loading weights:  85%|████████▍ | 361/427 [00:10<00:02, 27.33it/s]
# Loading weights:  85%|████████▌ | 365/427 [00:10<00:02, 25.26it/s]
# Loading weights:  87%|████████▋ | 370/427 [00:10<00:01, 28.76it/s]
# Loading weights:  89%|████████▉ | 380/427 [00:10<00:01, 38.47it/s]
# Loading weights:  90%|█████████ | 385/427 [00:10<00:01, 32.26it/s]
# Loading weights:  92%|█████████▏| 394/427 [00:11<00:00, 41.56it/s]
# Loading weights:  94%|█████████▎| 400/427 [00:11<00:00, 34.50it/s]
# Loading weights:  96%|█████████▋| 411/427 [00:11<00:00, 47.54it/s]
# Loading weights:  98%|█████████▊| 418/427 [00:11<00:00, 31.38it/s]
# Loading weights: 100%|█████████▉| 425/427 [00:11<00:00, 35.09it/s]
# Loading weights: 100%|██████████| 427/427 [00:11<00:00, 35.69it/s]
# LLM loaded successfully.
# [transformers] Setting `pad_token_id` to `eos_token_id`:248044 for open-end generation.
# d:\Anaconda\envs\specllm\Lib\site-packages\bitsandbytes\backends\cuda\ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# LLM unloaded.
#                  scenario  n_location_years  mean_predicted_yield  mean_scenario_gain  n_stress_signals country   policy  schema_valid  grounded_recommendation_ratio  n_recommendations  n_grounded_recommendations
#    S1_observed_conditions                31              5.253104            0.000000               917      CN qwen_rag             1                            1.0                  6                           6
# S2_bounded_water_recovery                31              5.274550            0.021446               917      CN qwen_rag             1                            1.0                  6                           6
#    S1_observed_conditions                 9              6.327517            0.000000               366      ZA qwen_rag             1                            1.0                  6                           6
# S2_bounded_water_recovery                 9              6.409632            0.082116               366      ZA qwen_rag             1                            1.0                  6                           6
#    S1_observed_conditions                32              4.213349            0.000000              1441      MX qwen_rag             1                            1.0                  6                           6
# S2_bounded_water_recovery                32              4.581456            0.368107              1441      MX qwen_rag             1                            1.0                  6                           6
#    S1_observed_conditions                 5              9.045565            0.000000               177      PT qwen_rag             1                            1.0                  5                           5
# S2_bounded_water_recovery                 5              9.181205            0.135640               177      PT qwen_rag             1                            1.0                  5                           5
# 完成：06_stage3_run，耗时 21.0 分钟
# {'step': '06_stage3_run',
#  'module': 'cybench.stages.stage3_advisory.run',
#  'command': ['d:\\Anaconda\\envs\\specllm\\python.exe',
#   '-u',
#   '-m',
#   'cybench.stages.stage3_advisory.run',
#   '--countries',
#   'CN,ZA,MX,PT',
#   '--repeats',
#   '5',
#   '--base-seed',
#   '42',
#   '--advisors',
#   'qwen_rag',
#   '--stage1-output-dir',
#   'C:\\Users\\35454\\Downloads\\AgML-CY-Bench-main\\cybench\\output\\stages_split_aligned\\stage1_feature_engineering',
#   '--stage2-output-dir',
#   'C:\\Users\\35454\\Downloads\\AgML-CY-Bench-main\\cybench\\output\\stages_split_aligned\\stage2_tabpfn_transfer\\evaluation',
#   '--output-dir',
#   'C:\\Users\\35454\\Downloads\\AgML-CY-Bench-main\\cybench\\output\\stages_split_aligned\\stage3_advisory'],
#  'return_code': 0,
#  'elapsed_seconds': 1257.236349105835}

# %% [markdown]
# ## 完整性审计：每个模型必须有五次 train/test

# %%
EXPECTED_REPEATS = set(range(1, REPEATS + 1))
EXPECTED_SPLITS = {'train', 'test'}

def audit_prediction_files(paths, label, expected_count):
    paths = list(paths)
    problems = []
    for path in paths:
        frame = pd.read_csv(path)
        repeats = set(pd.to_numeric(frame.get('repeat'), errors='coerce').dropna().astype(int))
        splits = set(frame.get('split', pd.Series(dtype=str)).dropna().astype(str))
        if repeats != EXPECTED_REPEATS or splits != EXPECTED_SPLITS:
            problems.append({'path': str(path), 'repeats': sorted(repeats), 'splits': sorted(splits)})
    result = {'stage': label, 'files': len(paths), 'expected_files': expected_count, 'invalid_files': len(problems)}
    print(result)
    if len(paths) != expected_count or problems:
        raise AssertionError({'summary': result, 'problems': problems[:10]})
    return result

audit = []
audit.append(audit_prediction_files(
    STAGE1.glob('results/maize_*/*/predictions_*.csv'), 'stage1',
    len(COUNTRIES) * len(ADVISORS) * len(MODELS),
))
audit.append(audit_prediction_files(
    STAGE2.glob('maize_*/predictions_*.csv'), 'stage2', len(COUNTRIES) * 2,
))
audit.append(audit_prediction_files(
    STAGE3.glob('maize_*/model_predictions.csv'), 'stage3', len(COUNTRIES),
))

required_summaries = [
    STAGE1 / 'results' / 'metrics_all.csv', STAGE1 / 'results' / 'metrics_summary.csv',
    STAGE2 / 'metrics_all.csv', STAGE2 / 'metrics_summary.csv',
]
required_summaries += [STAGE3 / f'maize_{country}' / 'model_validation_repeats.csv' for country in COUNTRIES]
required_summaries += [STAGE3 / f'maize_{country}' / 'model_validation_summary.csv' for country in COUNTRIES]
for path in required_summaries:
    require_file(path)

completion = {
    'completed_at': datetime.now().isoformat(), 'countries': COUNTRIES,
    'advisors': ADVISORS, 'models': MODELS, 'repeats': REPEATS,
    'base_seed': BASE_SEED, 'audit': audit,
}
completion_path = STAGE_ROOT / 'stage123_abl_heat_hist_completion.json'
completion_path.write_text(json.dumps(completion, indent=2, ensure_ascii=False), encoding='utf-8')
print('全部完成并通过审计：', completion_path)
# Out:
# {'stage': 'stage1', 'files': 60, 'expected_files': 60, 'invalid_files': 0}
# {'stage': 'stage2', 'files': 8, 'expected_files': 8, 'invalid_files': 0}
# {'stage': 'stage3', 'files': 4, 'expected_files': 4, 'invalid_files': 0}
# 全部完成并通过审计： C:\Users\35454\Downloads\AgML-CY-Bench-main\cybench\output\stages_split_aligned\stage123_abl_heat_hist_completion.json
